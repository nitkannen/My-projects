# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 =pd.read_excel('COVID-19-3.27.top30.xlsx')

# %%
df1.head()
# Out:
#    country  Canada  China   Italy      US   Spain  Germany    Iran  France  \
# 0        1   657.0    548   655.0   518.0   500.0    670.0   593.0   653.0
# 1        2   800.0    643   888.0   583.0   673.0    799.0   978.0   949.0
# 2        3   943.0    920  1128.0   959.0  1073.0   1040.0  1501.0  1126.0
# 3        4  1277.0   1406  1694.0  1281.0  1695.0   1176.0  2336.0  1209.0
# 4        5  1469.0   2075  2036.0  1663.0  2277.0   1457.0  2922.0  1784.0
#
#    United Kingdom    ...     Malaysia  Czechia  Denmark  Ireland  Luxembourg  \
# 0           456.0    ...        566.0    694.0    617.0    557.0       670.0
# 1           798.0    ...        673.0    833.0    804.0    683.0       798.0
# 2          1140.0    ...        790.0    995.0    836.0    785.0       875.0
# 3          1140.0    ...        900.0   1120.0    875.0    906.0      1099.0
# 4          1543.0    ...       1030.0   1236.0    933.0   1125.0      1333.0
#
#    Japan  Ecuador   Chile  Poland  Pakistan
# ...

# %%
plt.figure(figsize = (15,15))
plt.plot(x = np.arange(len(df1["Italy"])),y = df1['Italy'])
# Out:
# []

# %%
symptoms={'Symptom':['Fever',
        'Dry cough',
        'Fatigue',
        'Sputum production',
        'Shortness of breath',
        'Muscle pain',
        'Sore throat',
        'Headache',
        'Chills',
        'Nausea or vomiting',
        'Nasal congestion',
        'Diarrhoea',
        'Haemoptysis',
        'Conjunctival congestion'],'Percentage':[87.9,67.7,38.1,33.4,18.6,14.8,13.9,13.6,11.4,5.0,4.8,3.7,0.9,0.8]}

# %%
df = pd.DataFrame(symptoms)

# %%
df.head()
# Out:
#                Symptom  Percentage
# 0                Fever        87.9
# 1            Dry cough        67.7
# 2              Fatigue        38.1
# 3    Sputum production        33.4
# 4  Shortness of breath        18.6

# %%
plt.figure(figsize = (25,13))
sns.set_style(style='darkgrid')
sns.set_context('notebook',font_scale = 3)
sns.set_color_codes(palette = 'pastel')
ax= sns.barplot(x = 'Symptom',y = 'Percentage',data = df)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45,ha = 'right')    
plt.tight_layout()
plt.title("Covid Symptom Weigthage")
# Out:
# Text(0.5, 1.0, 'Covid Symptom Weigthage')

# %%
plt.figure(figsize = (15,15))
plt.title("Symptoms of CoronaVirus",fontsize = 40)
plt.pie(df['Percentage'],autopct='%.5f%%',center =(-200,0),radius = 0.6,shadow = True,textprops = {'fontsize' : 12})
plt.legend(df["Symptom"],loc = 0,fontsize = 16)
sns.set_palette('deep')
#plt.legend(df["Symptom"])
plt.tight_layout()

# %%
import math

# %%
##Analysing Paient Data (Korea)

# %%
df_patients = pd.read_csv('PatientInfo.csv')

# %%
df_patients.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
df_patients.isnull().sum()
# Out:
# patient_id               0
# global_num            1160
# sex                     94
# birth_year             464
# age                      0
# country                 90
# province                 0
# city                    76
# disease               3110
# infection_case         819
# infection_order       3097
# infected_by           2393
# contact_number        2539
# symptom_onset_date    2682
# confirmed_date           0
# released_date         2147
# deceased_date         3072
# state                    0
# dtype: int64

# %%
df_patients.drop(['disease','infection_order','infected_by','contact_number','symptom_onset_date','released_date','deceased_date','global_num'],axis = 1,inplace = True)

# %%
df_patients.head()
# Out:
#    patient_id     sex  birth_year  age country province         city  \
# 0  1000000001    male      1964.0  50s   Korea    Seoul   Gangseo-gu
# 1  1000000002    male      1987.0  30s   Korea    Seoul  Jungnang-gu
# 2  1000000003    male      1964.0  50s   Korea    Seoul    Jongno-gu
# 3  1000000004    male      1991.0  20s   Korea    Seoul      Mapo-gu
# 4  1000000005  female      1992.0  20s   Korea    Seoul  Seongbuk-gu
#
#          infection_case confirmed_date     state
# 0       overseas inflow     2020-01-23  released
# 1       overseas inflow     2020-01-30  released
# 2  contact with patient     2020-01-30  released
# 3       overseas inflow     2020-01-30  released
# 4  contact with patient     2020-01-31  released

# %%
len(df_patients)
# Out:
# 3128

# %%
df_patients.isnull().sum()
# Out:
# patient_id          0
# sex                94
# birth_year        464
# age               105
# country            90
# province            0
# city               76
# infection_case    819
# confirmed_date      0
# state               0
# dtype: int64

# %%
df_patients.dropna(inplace = True)

# %%
plt.figure(figsize=(10,6))
plt.title('State of patients gender-wise',fontsize = 20)
sns.set_context(context = 'notebook',font_scale = 1.2)
sns.countplot(x = 'state',data = df_patients,hue = 'sex',palette = 'magma')

# %%
plt.figure(figsize = (30,15))
plt.title('Province-wise patient count',fontsize = 40)
sns.set_context(context = 'notebook',font_scale = 2)
sns.set_style(style = 'whitegrid')
ax= sns.countplot(x = 'province',data = df_patients,)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45,ha = 'right',fontsize = 25)
# Out:
# [Text(0, 0, 'Seoul'),
#  Text(0, 0, 'Gyeonggi-do'),
#  Text(0, 0, 'Chungcheongnam-do'),
#  Text(0, 0, 'Busan'),
#  Text(0, 0, 'Daegu'),
#  Text(0, 0, 'Incheon'),
#  Text(0, 0, 'Ulsan'),
#  Text(0, 0, 'Gangwon-do'),
#  Text(0, 0, 'Chungcheongbuk-do'),
#  Text(0, 0, 'Jeollabuk-do'),
#  Text(0, 0, 'Jeollanam-do'),
#  Text(0, 0, 'Gyeongsangbuk-do'),
#  Text(0, 0, 'Gyeongsangnam-do'),
#  Text(0, 0, 'Jeju-do')]

# %%
#This is done to remove the unnecessary s present in age column 
df_patients['age']= (df_patients['age'].apply(lambda x:float(str(x)[:1])*10))

# %%
plt.figure(figsize = (10,6))
plt.title("Age Distribution of admitted patients",fontsize = 30)
sns.set_style(style = 'darkgrid')
sns.distplot(df_patients['age'],color = 'green')
# Out:
# C:\Users\senthilkumar\anaconda3\envs\nlp_course\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_patients.head()
# Out:
#    patient_id     sex  birth_year   age country province         city  \
# 0  1000000001    male      1964.0  50.0   Korea    Seoul   Gangseo-gu
# 1  1000000002    male      1987.0  30.0   Korea    Seoul  Jungnang-gu
# 2  1000000003    male      1964.0  50.0   Korea    Seoul    Jongno-gu
# 3  1000000004    male      1991.0  20.0   Korea    Seoul      Mapo-gu
# 4  1000000005  female      1992.0  20.0   Korea    Seoul  Seongbuk-gu
#
#          infection_case confirmed_date     state
# 0       overseas inflow     2020-01-23  released
# 1       overseas inflow     2020-01-30  released
# 2  contact with patient     2020-01-30  released
# 3       overseas inflow     2020-01-30  released
# 4  contact with patient     2020-01-31  released

# %%
dead = df_patients[df_patients['state']=='deceased']
rec = df_patients[df_patients['state']=='released']
iso =df_patients[df_patients['state']=='isolated']

# %%
ax1= plt.figure(figsize = (10,6))
plt.title("Covid consequences for different ages",fontsize = 30)
sns.set_style(style = 'whitegrid')
sns.set_color_codes(palette = 'deep')
sns.kdeplot(dead['age'],shade =True,color = 'r',label = 'Deceased',legend = False)
ax= sns.kdeplot(rec['age'],shade =True,legend = False,label = 'Recovered')
sns.kdeplot(iso['age'],shade = True,legend = False,color = 'y',label = 'isolated')
ax1.legend(loc = 7)
ax.set_xlabel("Age distribution",fontsize = 18)
# Out:
# Text(0.5, 0, 'Age distribution')

# %%
ax = plt.figure(figsize = (10,6))
sns.set_style('whitegrid')
sns.kdeplot(dead[dead['sex']=='female']['age'],label = 'Female',shade = True,legend =False,color = 'b')
ax1= sns.kdeplot(dead[dead['sex']=='male']['age'],label = 'Male',shade = True,legend = False,color = 'r')
ax.legend(loc = 7)
plt.title("Sex-wise deceased",fontsize = 30)
ax1.set_xlabel("Age Distribution")
# Out:
# Text(0.5, 0, 'Age Distribution')

# %%
ax = plt.figure(figsize = (10,6))
sns.set_style('whitegrid')
sns.kdeplot(rec[rec['sex']=='female']['age'],label = 'Female',shade = True,legend =False,color = 'b')
ax1= sns.kdeplot(rec[rec['sex']=='male']['age'],label = 'Male',shade = True,legend = False,color = 'r')
ax.legend(loc = 7)
plt.title("Sex-wise recovered",fontsize = 30)
ax1.set_xlabel("Age Distribution")
# Out:
# Text(0.5, 0, 'Age Distribution')

# %%
 a= df_patients.pivot_table(index ='state',columns = 'sex',values = 'age')

# %%
plt.title('Age(mean)')

sns.heatmap(a)

# %%
plt.figure(figsize=(10,6))
plt.title('Age vs States')
sns.violinplot(x = 'state',y = 'age',data = df_patients)

#sns.boxplot(x = 'state',y = 'age',data = df_patients)

# %%
plt.figure(figsize=(8,4))
plt.title('Age vs Sex')
sns.boxplot(x = 'sex',y = 'age',data = df_patients)
